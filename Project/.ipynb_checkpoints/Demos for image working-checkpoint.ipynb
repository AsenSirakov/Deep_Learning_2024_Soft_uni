# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import os
from PIL import Image
import imagehash
import torch
from collections import Counter

# %%
import matplotlib.pyplot as plt
from PIL import Image
import os

train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

# Check the distribution of classes
print(train_df['label'].value_counts())

# Check a sample of images and their sizes
train_images_path = 'train_data'
test_images_path = 'test_data'

# Get one image from each label
label_0_image = train_df[train_df['label'] == 0].iloc[0]['file_name']
label_1_image = train_df[train_df['label'] == 1].iloc[0]['file_name']

# Paths
label_0_path = os.path.join(train_images_path, label_0_image.replace("train_data/", ""))
label_1_path = os.path.join(train_images_path, label_1_image.replace("train_data/", ""))

# Display images
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
for idx, (label, path) in enumerate([(0, label_0_path), (1, label_1_path)]):
    try:
        img = Image.open(path)
        ax[idx].imshow(img)
        ax[idx].set_title(f"Label {label}")
        ax[idx].axis("off")
    except FileNotFoundError:
        print(f"File not found: {path}")
plt.tight_layout()
plt.show()
# Out:
# label
# 1    39975
# 0    39975
# Name: count, dtype: int64

# %%
import os
import pandas as pd
from PIL import Image
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from torch.optim import Adam
from torch.amp import GradScaler, autocast
from tqdm import tqdm

# Dataset Class
class ImageDataset(Dataset):
    def __init__(self, dataframe, root_dir, transform=None):
        self.dataframe = dataframe
        self.root_dir = root_dir
        self.transform = transform

        # Validate file paths
        valid_rows = []
        for _, row in self.dataframe.iterrows():
            img_path = os.path.join(self.root_dir, row["file_name"])
            if os.path.exists(img_path):
                valid_rows.append(row)
        self.dataframe = pd.DataFrame(valid_rows)

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        img_name = os.path.join(self.root_dir, self.dataframe.iloc[idx]["file_name"])
        label = self.dataframe.iloc[idx]["label"]

        try:
            image = Image.open(img_name).convert("RGB")
        except Exception as e:
            print(f"Error loading image {img_name}: {e}")
            return None, None

        if self.transform:
            image = self.transform(image)

        return image, int(label)

# Training Script
if __name__ == "__main__":
    # Paths
    train_csv_path = "GitHub/Deep_Learning_2024_Soft_uni/Project/train.csv"
    train_dir = "GitHub/Deep_Learning_2024_Soft_uni/Project/train_data"

    # Load Dataset
    train_df = pd.read_csv(train_csv_path).sample(n=20000, random_state=42)
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    train_dataset = ImageDataset(train_df, train_dir, transform=transform)

    # DataLoader with custom worker initialization
    def worker_init_fn(worker_id):
        print(f"Worker {worker_id} initialized")

    train_loader = DataLoader(
        train_dataset,
        batch_size=16,
        shuffle=True,
        num_workers=4,  # Start with 1 and increase gradually
        pin_memory=True,
        worker_init_fn=worker_init_fn
    )

    # Model
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
    num_features = model.fc.in_features
    model.fc = nn.Linear(num_features, 1)
    model = model.to(device)

    # Loss, Optimizer, and Scaler
    criterion = nn.BCEWithLogitsLoss()
    optimizer = Adam(model.parameters(), lr=1e-4)
    scaler = GradScaler()

    # Training Loop
    epochs = 5
    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        progress_bar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{epochs}", unit="batch")

        for batch_idx, (images, labels) in enumerate(progress_bar):
            if images is None or labels is None:
                continue

            images, labels = images.to(device), labels.to(device).float()

            optimizer.zero_grad()
            with autocast(device_type="cuda" if torch.cuda.is_available() else "cpu"):
                outputs = model(images).squeeze()
                loss = criterion(outputs, labels)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            running_loss += loss.item()
            progress_bar.set_postfix(loss=loss.item())

        epoch_loss = running_loss / len(train_loader)
        print(f"Epoch [{epoch+1}/{epochs}], Loss: {epoch_loss:.4f}")

    # Save the Model
    torch.save(model.state_dict(), "resnet18_trained.pth")
    print("Training complete. Model saved.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 52
#      49 train_dir = "GitHub/Deep_Learning_2024_Soft_uni/Project/train_data"
#      51 # Load Dataset
# ---> 52 train_df = pd.read_csv(train_csv_path).sample(n=20000, random_state=42)
#      53 transform = transforms.Compose([
#      54     transforms.Resize((224, 224)),
#      55     transforms.ToTensor(),
#      56     transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#      57 ])
#      58 train_dataset = ImageDataset(train_df, train_dir, transform=transform)
#
# ...
